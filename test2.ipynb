# %%
import pandas as pd
import numpy as np
from matplotlib.pyplot import plot

# %%
dt=pd.read_csv(r'C:\Program Files\AppleStore.csv')

# %%
dt.head()
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium   100788224
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
#
#   currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 0      USD   3.99             21292                26          4.0
# 1      USD   0.00            161065                26          4.0
# 2      USD   0.00            188583              2822          3.5
# 3      USD   0.00            262241               649          4.0
# 4      USD   0.00            985920              5320          4.5
#
#    user_rating_ver     ver cont_rating   prime_genre  sup_devices.num  \
# ...

# %%
dt.shape
# Out:
# (7197, 16)

# %%
dt.describe()
# Out:
#                  id    size_bytes        price  rating_count_tot  \
# count  7.197000e+03  7.197000e+03  7197.000000      7.197000e+03
# mean   8.631310e+08  1.991345e+08     1.726218      1.289291e+04
# std    2.712368e+08  3.592069e+08     5.833006      7.573941e+04
# min    2.816565e+08  5.898240e+05     0.000000      0.000000e+00
# 25%    6.000937e+08  4.692275e+07     0.000000      2.800000e+01
# 50%    9.781482e+08  9.715302e+07     0.000000      3.000000e+02
# 75%    1.082310e+09  1.819249e+08     1.990000      2.793000e+03
# max    1.188376e+09  4.025970e+09   299.990000      2.974676e+06
#
#        rating_count_ver  user_rating  user_rating_ver  sup_devices.num  \
# count       7197.000000  7197.000000      7197.000000      7197.000000
# mean         460.373906     3.526956         3.253578        37.361817
# std         3920.455183     1.517948         1.809363         3.737715
# min            0.000000     0.000000         0.000000         9.000000
# ...

# %%
dt.shape
# Out:
# (7197, 16)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
import sklearn as sk

# %%
sk.preprocessing.scale
# Out:
# <function sklearn.preprocessing.data.scale(X, axis=0, with_mean=True, with_std=True, copy=True)>

# %%
dt.head(5)
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium   100788224
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
#
#   currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 0      USD   3.99             21292                26          4.0
# 1      USD   0.00            161065                26          4.0
# 2      USD   0.00            188583              2822          3.5
# 3      USD   0.00            262241               649          4.0
# 4      USD   0.00            985920              5320          4.5
#
#    user_rating_ver     ver cont_rating   prime_genre  sup_devices.num  \
# ...

# %%
dt.data=dt.iloc[:,1:]
# Out:
# C:\Users\Rahul\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
dt.data.head()
# Out:
#                                           track_name  size_bytes currency  \
# 0                                    PAC-MAN Premium   100788224      USD
# 1                          Evernote - stay organized   158578688      USD
# 2    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032      USD
# 3  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 4                                              Bible    92774400      USD
#
#    price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 0   3.99             21292                26          4.0              4.5
# 1   0.00            161065                26          4.0              3.5
# 2   0.00            188583              2822          3.5              4.5
# 3   0.00            262241               649          4.0              4.5
# 4   0.00            985920              5320          4.5              5.0
#
# ...

# %%
dt.drop(columns='prime_genre', axis=1)
# Out:
#               id                                         track_name  \
# 0      281656475                                    PAC-MAN Premium
# 1      281796108                          Evernote - stay organized
# 2      281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3      282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4      282935706                                              Bible
# 5      283619399                                   Shanghai Mahjong
# 6      283646709             PayPal - Send and request money safely
# 7      284035177                            Pandora - Music & Radio
# 8      284666222                        PCalc - The Best Calculator
# 9      284736660                                        Ms. PAC-MAN
# 10     284791396                          Solitaire by MobilityWare
# 11     284815117                                   SCRABBLE Premium
# 12     284815942               Google – Search made just for mobile
# ...

# %%
c=dt.drop(columns='prime_genre', axis=1)

# %%
c
# Out:
#               id                                         track_name  \
# 0      281656475                                    PAC-MAN Premium
# 1      281796108                          Evernote - stay organized
# 2      281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3      282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4      282935706                                              Bible
# 5      283619399                                   Shanghai Mahjong
# 6      283646709             PayPal - Send and request money safely
# 7      284035177                            Pandora - Music & Radio
# 8      284666222                        PCalc - The Best Calculator
# 9      284736660                                        Ms. PAC-MAN
# 10     284791396                          Solitaire by MobilityWare
# 11     284815117                                   SCRABBLE Premium
# 12     284815942               Google – Search made just for mobile
# ...

# %%
dt_normal=scale(dt.data)
type(dt_normal)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-e7a18e432c45> in <module>()
# ----> 1 dt_normal=scale(dt.data)
#       2 type(dt_normal)
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in scale(X, axis, with_mean, with_std, copy)
#     131     X = check_array(X, accept_sparse='csc', copy=copy, ensure_2d=False,
#     132                     warn_on_dtype=True, estimator='the scale function',
# --> 133                     dtype=FLOAT_DTYPES)
#     134     if sparse.issparse(X):
#     135         if with_mean:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from sklearn.preprocessing import scale
import sklearn as sl

# %%
dt
# Out:
#               id                                         track_name  \
# 0      281656475                                    PAC-MAN Premium
# 1      281796108                          Evernote - stay organized
# 2      281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3      282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4      282935706                                              Bible
# 5      283619399                                   Shanghai Mahjong
# 6      283646709             PayPal - Send and request money safely
# 7      284035177                            Pandora - Music & Radio
# 8      284666222                        PCalc - The Best Calculator
# 9      284736660                                        Ms. PAC-MAN
# 10     284791396                          Solitaire by MobilityWare
# 11     284815117                                   SCRABBLE Premium
# 12     284815942               Google – Search made just for mobile
# ...

# %%
df_normal=scale(c.iloc[:,1:])
type(df_normal)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-e434f45d60dd> in <module>()
# ----> 1 df_normal=scale(c.iloc[:,1:])
#       2 type(df_normal)
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in scale(X, axis, with_mean, with_std, copy)
#     131     X = check_array(X, accept_sparse='csc', copy=copy, ensure_2d=False,
#     132                     warn_on_dtype=True, estimator='the scale function',
# --> 133                     dtype=FLOAT_DTYPES)
#     134     if sparse.issparse(X):
#     135         if with_mean:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# ...

# %%
d=c.drop(columns='cont_rating')

# %%
d
# Out:
#               id                                         track_name  \
# 0      281656475                                    PAC-MAN Premium
# 1      281796108                          Evernote - stay organized
# 2      281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3      282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4      282935706                                              Bible
# 5      283619399                                   Shanghai Mahjong
# 6      283646709             PayPal - Send and request money safely
# 7      284035177                            Pandora - Music & Radio
# 8      284666222                        PCalc - The Best Calculator
# 9      284736660                                        Ms. PAC-MAN
# 10     284791396                          Solitaire by MobilityWare
# 11     284815117                                   SCRABBLE Premium
# 12     284815942               Google – Search made just for mobile
# ...

# %%
df_normal=scale(d.iloc[:,1:])
type(df_normal)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-ffcb41b27c68> in <module>()
# ----> 1 df_normal=scale(d.iloc[:,1:])
#       2 type(df_normal)
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in scale(X, axis, with_mean, with_std, copy)
#     131     X = check_array(X, accept_sparse='csc', copy=copy, ensure_2d=False,
#     132                     warn_on_dtype=True, estimator='the scale function',
# --> 133                     dtype=FLOAT_DTYPES)
#     134     if sparse.issparse(X):
#     135         if with_mean:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# ...

# %%
e=d.drop(columns='ver')

# %%
e
# Out:
#               id                                         track_name  \
# 0      281656475                                    PAC-MAN Premium
# 1      281796108                          Evernote - stay organized
# 2      281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3      282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4      282935706                                              Bible
# 5      283619399                                   Shanghai Mahjong
# 6      283646709             PayPal - Send and request money safely
# 7      284035177                            Pandora - Music & Radio
# 8      284666222                        PCalc - The Best Calculator
# 9      284736660                                        Ms. PAC-MAN
# 10     284791396                          Solitaire by MobilityWare
# 11     284815117                                   SCRABBLE Premium
# 12     284815942               Google – Search made just for mobile
# ...

# %%
df_normal=scale(e.iloc[:,1:])
type(df_normal)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-c047066257f8> in <module>()
# ----> 1 df_normal=scale(e.iloc[:,1:])
#       2 type(df_normal)
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in scale(X, axis, with_mean, with_std, copy)
#     131     X = check_array(X, accept_sparse='csc', copy=copy, ensure_2d=False,
#     132                     warn_on_dtype=True, estimator='the scale function',
# --> 133                     dtype=FLOAT_DTYPES)
#     134     if sparse.issparse(X):
#     135         if with_mean:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# ...

# %%
f=e.drop(columns='currency')

# %%
f
# Out:
#               id                                         track_name  \
# 0      281656475                                    PAC-MAN Premium
# 1      281796108                          Evernote - stay organized
# 2      281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3      282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4      282935706                                              Bible
# 5      283619399                                   Shanghai Mahjong
# 6      283646709             PayPal - Send and request money safely
# 7      284035177                            Pandora - Music & Radio
# 8      284666222                        PCalc - The Best Calculator
# 9      284736660                                        Ms. PAC-MAN
# 10     284791396                          Solitaire by MobilityWare
# 11     284815117                                   SCRABBLE Premium
# 12     284815942               Google – Search made just for mobile
# ...

# %%
g=f.drop(columns='track_name')

# %%
g
# Out:
#               id  size_bytes  price  rating_count_tot  rating_count_ver  \
# 0      281656475   100788224   3.99             21292                26
# 1      281796108   158578688   0.00            161065                26
# 2      281940292   100524032   0.00            188583              2822
# 3      282614216   128512000   0.00            262241               649
# 4      282935706    92774400   0.00            985920              5320
# 5      283619399    10485713   0.99              8253              5516
# 6      283646709   227795968   0.00            119487               879
# 7      284035177   130242560   0.00           1126879              3594
# 8      284666222    49250304   9.99              1117                 4
# 9      284736660    70023168   3.99              7885                40
# 10     284791396    49618944   4.99             76720              4017
# 11     284815117   227547136   7.99            105776               166
# ...

# %%
df_normal=scale(g.iloc[:,1:])
type(df_normal)
# Out:
# numpy.ndarray

# %%
df_normal
# Out:
# array([[-0.27380615,  0.38812569,  0.11090232, ...,  0.65105067,
#          0.57647077,  0.08364175],
#        [-0.11291148, -0.29596024,  1.95647669, ...,  0.65105067,
#          2.21808338,  0.08364175],
#        [-0.27454169, -0.29596024,  2.31982667, ...,  0.65105067,
#         -0.30747447,  0.08364175],
#        ...,
#        [-0.24447871,  0.04522548, -0.17004096, ..., -1.36318325,
#         -0.56003026,  0.08364175],
#        [-0.283696  , -0.29596024, -0.16911668, ..., -1.86674173,
#         -0.43375237,  0.08364175],
#        [-0.30134036, -0.29596024, -0.17019941, ..., -1.86674173,
#         -0.43375237,  0.08364175]])

# %%
df_normal=pd.DataFrame(df_normal)
type(df_normal)
# Out:
# pandas.core.frame.DataFrame

# %%
from scipy.cluster.hierarchy import linkage
import scipy.cluster.hierarchy as sch

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
p=AgglomerativeClustering(n_clusters=5, linkage='complete', affinity='euclidean').fit(df_normal)
p.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.decomposition import PCA

# %%
pca_values=PCA()
pca=pca_values.fit_transform(g)

# %%
type(pca_values)
# Out:
# sklearn.decomposition.pca.PCA

# %%
pca
# Out:
# array([[-1.74531549e+08,  5.63314601e+08, -2.42380180e+04, ...,
#         -9.13473380e-01, -6.28664151e-01, -5.56615096e-03],
#        [-1.17232216e+08,  5.70834162e+08,  1.15291486e+05, ...,
#         -1.52980653e+00,  3.57997664e-02, -3.10699050e-03],
#        [-1.74755802e+08,  5.62998287e+08,  1.43087330e+05, ...,
#         -1.15344470e+00, -9.77257010e-01, -7.13215285e-03],
#        ...,
#        [-4.40179897e+07, -3.33421798e+08,  5.94839784e+03, ...,
#          1.39567527e+00,  2.90477774e+00, -2.50650591e-03],
#        [-5.79720631e+07, -3.35347102e+08,  6.08220246e+03, ...,
#          4.22924848e+00,  1.53458777e-01, -8.60634766e-03],
#        [-6.41825570e+07, -3.36719126e+08,  6.05757125e+03, ...,
#          4.62103821e+00,  2.52719937e-01, -9.02769987e-03]])
